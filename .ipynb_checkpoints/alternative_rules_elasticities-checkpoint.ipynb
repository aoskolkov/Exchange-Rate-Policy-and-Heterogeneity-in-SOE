# %%
using Compat, Random, Distributions, Plots, LinearAlgebra, Statistics, LaTeXStrings, SparseArrays, CPUTime, JLD2
using SpecialFunctions, GSL, SuiteSparse, Distributed, Roots, NBInclude
gr(fmt=:png)
e = 2.7182818284
Random.seed!(1);

# %%
addprocs(2)
@everywhere using Compat, Random, Distributions, Plots, LinearAlgebra, Statistics, LaTeXStrings, SparseArrays, CPUTime, JLD2, SpecialFunctions, GSL, SuiteSparse, Distributed
@everywhere using SharedArrays, ParallelDataTransfer, Roots, NBInclude
@everywhere @nbinclude("setup.ipynb")
@everywhere using .setup, .functions
procs()
# Out:
# 3-element Vector{Int64}:
#  1
#  2
#  3

# %%
# set the time grid
T = 600
dt = T/1200
T_bar = 24
time_grid = collect(0:dt:T)
L = length(time_grid)
t_grid = dt, L
ψ = 0.02/12*exp.(-time_grid/12*1.15)

# set up matrices that convert monthly responses to quarterly
Lq = Int64((L-1)/8)
A = Diagonal(ones(Lq))
b = ones(8)'/8
Q = hcat(kron(A,b),zeros(Lq));

# %%
# compute steady-state statistics
@load "steady_state_output.jld2"
@load "external_parameters.jld2"
par_grid_N, par_grid_T = deepcopy(par_grid), deepcopy(par_grid)
par_grid_N.labor = par_grid.labor * prod_N
par_grid_N.productivity = par_grid.productivity * prod_N
par_grid_T.labor = par_grid.labor * prod_T
par_grid_T.productivity = par_grid.productivity * prod_T
aN = distr_N'*par_grid.assets
aT = distr_T'*par_grid.assets
a = par.ζ_T*aT + par.ζ_N*aN

@time paral = pmap(q_response,[value_N,value_T],[distr_N,distr_T],(1-par.τ_w)*[ones(L),ones(L)],[par.r_d*ones(L),par.r_d*ones(L)],[zeros(L),zeros(L)],[true,true],[par,par],[par_grid_N,par_grid_T],[t_grid,t_grid])
 
Cq_N, Lq_N, v_N = paral[1]
Cq_T, Lq_T, v_T = paral[2]

ss_objects = Cq_T, Cq_N, distr_T, distr_N;
# Out:
#  40.752511 seconds (20.79 M allocations: 1.135 GiB, 0.93% gc time, 11.69% compilation time)

# %%
Δvars, biases_T, biases_N, P_arr, E_arr, r_arr, μ_arr, cN_arr, cT_arr, wN_arr, wT_arr = [], [], [], [], [], [], [], [], [], [], []
var_total = 0.0

ress = ["peg_low_elast", "low_075", "low_050", "low_025", "float_low_elast", "low_025_neg", "low_050_neg", "low_075_neg", 
    "peg", "mix_075", "mix_050", "mix_025", "float", "mix_025_neg", "mix_050_neg", "mix_075_neg", 
    "peg_high_elast", "high_075", "high_050", "high_025", "float_high_elast", "high_025_neg", "high_050_neg", "high_075_neg"]

for i in 1:length(ress)
    @load "transition_results/"*ress[i]*".jld2" res_this
    
    print(ress[i]," ")

    @time paral = pmap(q_response,[value_N,value_T],[distr_N,distr_T],(1-par.τ_w)*[res_this.wN_sequence,res_this.wT_sequence],[res_this.rd_sequence,res_this.rd_sequence],[zeros(L),zeros(L)],[true,true],[par,par],[par_grid_N,par_grid_T],[t_grid,t_grid])
    Call_N, Lall_N, Wall_N = paral[1]
    Call_T, Lall_T, Wall_T = paral[2]
    
    var_Q_total, var_total, change_var, disp_T, disp_N, bias_T, bias_N, betw = print_decomposition(Call_T,Call_N,par,par_grid,ss_objects)
    append!(Δvars,change_var)
    append!(biases_T,bias_T)
    append!(biases_N,bias_N)
    
    P_seq = exp.(cumsum(vcat(0,res_this.π_sequence[1:end-1]) * dt))
    E_seq = P_seq.*res_this.pF_sequence
    
    append!(P_arr,100*(Q*P_seq)[1]-100)
    append!(E_arr,100*(Q*E_seq)[1]-100)
    append!(r_arr,100*12*((Q*res_this.rd_sequence)[1]-par.r_d))
    append!(μ_arr,100*12*(Q*res_this.μ_sequence)[1])
    append!(cN_arr,100*(Q*res_this.cN_sequence)[1]/res_this.cN_sequence[end]-100)
    append!(cT_arr,100*(Q*res_this.cT_sequence)[1]/res_this.cT_sequence[end]-100)
    append!(wN_arr,100*(Q*res_this.wN_sequence)[1]-100)
    append!(wT_arr,100*(Q*res_this.wT_sequence)[1]-100)
    
    print("\nP = ",round(P_arr[end],digits=2)," E = ",round(E_arr[end],digits=2)," r = ",round(r_arr[end],digits=2)," μ = ",round(μ_arr[end],digits=2))
    print(", cN = ",round(cN_arr[end],digits=2)," cT = ",round(cT_arr[end],digits=2)," wN = ",round(wN_arr[end],digits=2)," wT = ",round(wT_arr[end],digits=2),"\n")
end
# Out:
# peg_low_elast  21.457239 seconds (25.92 k allocations: 2.214 MiB, 0.07% compilation time)
# change in variance = 1.59%: dispersion T = 0.05%, dispersion N = 0.36%, wealth bias T = 8.13%, wealth bias N = 36.33%, between = 55.12%
# P = -0.78 E = 0.0 r = 4.08 μ = 2.38, cN = -0.48 cT = -0.1 wN = -1.06 wT = -0.06
# low_075  20.643769 seconds (1.10 k allocations: 866.500 KiB)
# change in variance = -0.26%: dispersion T = -0.86%, dispersion N = -0.22%, wealth bias T = 168.53%, wealth bias N = 94.24%, between = -161.69%
# P = 1.38 E = 3.33 r = -0.72 μ = -2.42, cN = 0.7 cT = 0.88 wN = 0.88 wT = 1.39
# low_050  20.629009 seconds (1.11 k allocations: 867.922 KiB)
# change in variance = 0.18%: dispersion T = 0.63%, dispersion N = 0.02%, wealth bias T = -168.84%, wealth bias N = -30.36%, between = 298.56%
# P = 0.56 E = 1.81 r = 0.08 μ = -1.62, cN = 0.02 cT = 0.26 wN = 0.07 wT = 0.66
# low_025  20.899559 seconds (1.11 k allocations: 867.750 KiB)
# change in variance = 0.32%: dispersion T = 0.26%, dispersion N = 0.0%, wealth bias T = -78.82%, wealth bias N = 2.83%, between = 175.73%
# P = 0.28 E = 1.3 r = 0.34 μ = -1.36, cN = -0.2 cT = 0.05 wN = -0.19 wT = 0.42
# float_low_elast  20.216160 seconds (1.09 k allocations: 867.328 KiB)
# change in variance = 0.4%: dispersion T = 0.18%, dispersion N = 0.01%, wealth bias T = -58.62%, wealth bias N = 10.28%, between = 148.15%
# P = 0.15 E = 1.05 r = 0.47 μ = -1.23, cN = -0.31 cT = -0.05 wN = -0.33 wT = 0.3
# low_025_neg  20.336015 seconds (1.10 k allocations: 868.141 KiB)
# change in variance = 0.44%: dispersion T = 0.15%, dispersion N = 0.01%, wealth bias T = -49.7%, wealth bias N = 13.57%, between = 135.97%
# P = 0.07 E = 0.9 r = 0.55 μ = -1.15, cN = -0.38 cT = -0.11 wN = -0.41 wT = 0.23
# low_050_neg  21.249422 seconds (1.12 k allocations: 868.375 KiB)
# change in variance = 0.47%: dispersion T = 0.13%, dispersion N = 0.02%, wealth bias T = -44.67%, wealth bias N = 15.42%, between = 129.1%
# P = 0.01 E = 0.8 r = 0.61 μ = -1.09, cN = -0.42 cT = -0.15 wN = -0.46 wT = 0.18
# low_075_neg  20.455208 seconds (1.08 k allocations: 866.016 KiB)
# change in variance = 0.49%: dispersion T = 0.12%, dispersion N = 0.02%, wealth bias T = -41.45%, wealth bias N = 16.61%, between = 124.69%
# P = -0.03 E = 0.73 r = 0.65 μ = -1.06, cN = -0.46 cT = -0.18 wN = -0.5 wT = 0.15
# peg  20.260070 seconds (1.10 k allocations: 867.344 KiB)
# change in variance = 0.84%: dispersion T = 0.05%, dispersion N = 0.2%, wealth bias T = -4.27%, wealth bias N = 34.9%, between = 69.12%
# P = -0.5 E = 0.0 r = 3.3 μ = 1.6, cN = -0.52 cT = -0.27 wN = -0.71 wT = -0.02
# mix_075  20.372160 seconds (1.10 k allocations: 867.109 KiB)
# change in variance = -0.46%: dispersion T = -0.61%, dispersion N = -0.24%, wealth bias T = 104.33%, wealth bias N = 70.59%, between = -74.07%
# P = 1.44 E = 3.26 r = -0.53 μ = -2.23, cN = 0.68 cT = 0.83 wN = 1.02 wT = 1.43
# mix_050  20.570620 seconds (1.11 k allocations: 867.812 KiB)
# change in variance = -0.09%: dispersion T = -1.73%, dispersion N = -0.31%, wealth bias T = 383.49%, wealth bias N = 164.52%, between = -445.97%
# P = 0.62 E = 1.71 r = 0.27 μ = -1.44, cN = 0.02 cT = 0.2 wN = 0.24 wT = 0.7
# mix_025  25.852527 seconds (1.25 k allocations: 870.891 KiB)
# change in variance = 0.03%: dispersion T = 3.8%, dispersion N = 0.47%, wealth bias T = -918.35%, wealth bias N = -273.61%, between = 1287.69%
# P = 0.34 E = 1.2 r = 0.53 μ = -1.17, cN = -0.2 cT = -0.01 wN = -0.03 wT = 0.46
# float  20.608290 seconds (1.11 k allocations: 866.453 KiB)
# change in variance = 0.1%: dispersion T = 1.17%, dispersion N = 0.12%, wealth bias T = -295.73%, wealth bias N = -64.01%, between = 458.45%
# P = 0.21 E = 0.95 r = 0.67 μ = -1.03, cN = -0.31 cT = -0.11 wN = -0.16 wT = 0.33
# mix_025_neg  20.006980 seconds (1.09 k allocations: 867.250 KiB)
# change in variance = 0.13%: dispersion T = 0.78%, dispersion N = 0.08%, wealth bias T = -202.42%, wealth bias N = -32.6%, between = 334.17%
# P = 0.13 E = 0.8 r = 0.75 μ = -0.95, cN = -0.37 cT = -0.18 wN = -0.23 wT = 0.26
# mix_050_neg  19.982733 seconds (1.08 k allocations: 866.859 KiB)
# change in variance = 0.16%: dispersion T = 0.63%, dispersion N = 0.06%, wealth bias T = -164.79%, wealth bias N = -19.94%, between = 284.04%
# P = 0.07 E = 0.69 r = 0.8 μ = -0.9, cN = -0.42 cT = -0.22 wN = -0.29 wT = 0.21
# mix_075_neg  20.027104 seconds (1.08 k allocations: 867.078 KiB)
# change in variance = 0.18%: dispersion T = 0.54%, dispersion N = 0.05%, wealth bias T = -144.45%, wealth bias N = -13.1%, between = 256.95%
# P = 0.03 E = 0.62 r = 0.84 μ = -0.86, cN = -0.45 cT = -0.25 wN = -0.32 wT = 0.18
# peg_high_elast  20.223523 seconds (1.09 k allocations: 867.172 KiB)
# change in variance = 0.29%: dispersion T = 0.21%, dispersion N = 0.15%, wealth bias T = -51.52%, wealth bias N = 24.86%, between = 126.3%
# P = -0.29 E = 0.0 r = 2.7 μ = 1.0, cN = -0.57 cT = -0.41 wN = -0.44 wT = -0.01
# high_075  20.771684 seconds (1.11 k allocations: 868.406 KiB)
# change in variance = -0.67%: dispersion T = -0.5%, dispersion N = -0.28%, wealth bias T = 77.57%, wealth bias N = 61.17%, between = -37.97%
# P = 1.5 E = 3.21 r = -0.35 μ = -2.05, cN = 0.68 cT = 0.78 wN = 1.17 wT = 1.46
# high_050  21.247078 seconds (1.12 k allocations: 867.859 KiB)
# change in variance = -0.33%: dispersion T = -0.6%, dispersion N = -0.24%, wealth bias T = 116.16%, wealth bias N = 72.09%, between = -87.42%
# P = 0.68 E = 1.65 r = 0.46 μ = -1.24, cN = 0.02 cT = 0.14 wN = 0.4 wT = 0.72
# high_025  20.601235 seconds (1.11 k allocations: 867.734 KiB)
# change in variance = -0.22%: dispersion T = -0.75%, dispersion N = -0.26%, wealth bias T = 155.53%, wealth bias N = 83.23%, between = -137.75%
# P = 0.4 E = 1.13 r = 0.73 μ = -0.97, cN = -0.2 cT = -0.07 wN = 0.14 wT = 0.47
# float_high_elast  20.198397 seconds (1.11 k allocations: 867.891 KiB)
# change in variance = -0.17%: dispersion T = -0.91%, dispersion N = -0.3%, wealth bias T = 195.48%, wealth bias N = 94.54%, between = -188.81%
# P = 0.27 E = 0.87 r = 0.86 μ = -0.84, cN = -0.31 cT = -0.17 wN = 0.02 wT = 0.35
# high_025_neg  20.555591 seconds (1.11 k allocations: 867.703 KiB)
# change in variance = -0.13%: dispersion T = -1.08%, dispersion N = -0.35%, wealth bias T = 236.01%, wealth bias N = 106.02%, between = -240.61%
# P = 0.19 E = 0.72 r = 0.94 μ = -0.76, cN = -0.37 cT = -0.24 wN = -0.06 wT = 0.28
# high_050_neg  20.212186 seconds (1.09 k allocations: 866.094 KiB)
# change in variance = -0.11%: dispersion T = -1.25%, dispersion N = -0.39%, wealth bias T = 277.11%, wealth bias N = 117.68%, between = -293.14%
# P = 0.13 E = 0.62 r = 1.0 μ = -0.7, cN = -0.42 cT = -0.28 wN = -0.11 wT = 0.23
# high_075_neg  20.253252 seconds (1.09 k allocations: 867.625 KiB)
# change in variance = -0.09%: dispersion T = -1.42%, dispersion N = -0.44%, wealth bias T = 318.77%, wealth bias N = 129.49%, between = -346.39%
# P = 0.1 E = 0.54 r = 1.04 μ = -0.66, cN = -0.45 cT = -0.31 wN = -0.15 wT = 0.19

# %%
ϕϵ_arr = [-Inf, 0.75, 0.5, 0.25, 0, -0.25, -0.5, -0.75]
ϕϵ_arr = repeat(ϕϵ_arr,3)
ϕπ_arr = 1.5*(ones(length(ϕϵ_arr))-ϕϵ_arr)
price_level_arr, inf_arr, psi_arr, logE_arr, π_arr, initial_depr, eventual_depr = [], [], [], [], [], [], []

for i in 1:length(ress)
    @load "transition_results/"*ress[i]*".jld2" res_this
    
    P_seq = exp.(cumsum(vcat(0,res_this.π_sequence[1:end-1]) * dt))
    E_seq = P_seq.*res_this.pF_sequence
    append!(logE_arr,(Q*log.(E_seq))[1])
end

# %%
degrees_of_fear = reverse([L"0.75",L"0.5",L"0.25",L"0",L"-0.25",L"-0.5",L"-0.75"])

Δgap = Δvars - biases_T - biases_N
plot_w = plot(1:7,reverse(wT_arr[2:8]),xticks=(1:7,degrees_of_fear),color=:black,label=L"\mathrm{T}",title=L"\mathrm{(a)\ wage\ response}",xlabel=L"\phi_\varepsilon",lw=2,legendfontsize=7)
plot!(1:7,reverse(wN_arr[18:end]),xticks=(1:7,degrees_of_fear),color=:beige,ms=5,markershape=:circle,label=L"\mathrm{N,\ high\ }\{\theta\}")
plot!(1:7,reverse(wN_arr[10:16]),xticks=(1:7,degrees_of_fear),color=:beige,ms=5,markershape=:diamond,label=L"\mathrm{N,\ baseline}")
plot!(1:7,reverse(wN_arr[2:8]),xticks=(1:7,degrees_of_fear),color=:beige,ms=5,markershape=:rect,label=L"\mathrm{N,\ low\ }\{\theta\}",legend=:topleft)
plot_C = plot(1:7,reverse(cT_arr[2:8]),xticks=(1:7,degrees_of_fear),color=:sienna,markershape=:rect,ms=5,label=L"\mathrm{T,\ low\ }\{\theta\}",title=L"\mathrm{(b)\ consumption\ response}",xlabel=L"\phi_\varepsilon",legendfontsize=7)
plot!(1:7,reverse(cT_arr[10:16]),xticks=(1:7,degrees_of_fear),color=:sienna,ms=5,markershape=:diamond,label=L"\mathrm{T,\ baseline}")
plot!(1:7,reverse(cT_arr[18:end]),xticks=(1:7,degrees_of_fear),color=:sienna,ms=5,markershape=:circle,label=L"\mathrm{T,\ high\ }\{\theta\}")
plot!(1:7,reverse(cN_arr[2:8]),xticks=(1:7,degrees_of_fear),color=:black,label=L"\mathrm{N}",legend=:topleft,lw=2)

matr_biases_N = reshape(biases_N,8,3)[2:end,:]
matr_biases_T = reshape(biases_T,8,3)[2:end,:]
matr_r = reshape(r_arr,8,3)[2:end,:]
matr_C = reshape(cT_arr-cN_arr,8,3)[2:end,:]
matr_w = reshape(wT_arr-wN_arr,8,3)[2:end,:]
matr_E = 100*reshape(logE_arr,8,3)[2:end,:]
matr_gaps = reshape(Δgap,8,3)[2:end,:]

clims = extrema(100*[matr_biases_T;matr_biases_N;matr_gaps]/var_total)
degrees_of_fear = reverse([L"0.75",L"0.50",L"0.25",L"\phi_\varepsilon\ \ 0",L"-0.25",L"-0.50",L"-0.75"])
plot_N_bias = heatmap(100*matr_biases_N/var_total,c=cgrad(:ice, rev=true),xticks=(1:3,[L"\mathrm{low}",L"\mathrm{baseline}",L"\mathrm{high}"]),yticks=(1:7,reverse(degrees_of_fear)),title=L"\mathrm{(d)\ wealth\ bias\ N}",colorbar=:false,clims=clims,xlabel=L"\{\theta\}")
plot_T_bias = heatmap(100*matr_biases_T/var_total,c=cgrad(:ice, rev=true),title=L"\mathrm{(e)\ wealth\ bias\ T}",xticks=(1:3,[L"\mathrm{low}",L"\mathrm{baseline}",L"\mathrm{high}"]),yticks=(1:7,reverse(degrees_of_fear)),colorbar=:false,clims=clims,xlabel=L"\{\theta\}")
plot_gaps = heatmap(100*matr_gaps/var_total,c=cgrad(:ice, rev=true),title=L"\mathrm{(f)\ change\ in\ gap}",xticks=(1:3,[L"\mathrm{low}",L"\mathrm{baseline}",L"\mathrm{high}"]),yticks=(1:7,reverse(degrees_of_fear)),colorbar=:true,clims=clims,xlabel=L"\{\theta\}")
plot_r = heatmap(matr_r,c=:algae,title=L"\mathrm{(c)\ real\ interest\ rate}",xticks=(1:3,[L"\mathrm{low}",L"\mathrm{baseline}",L"\mathrm{high}"]),yticks=(1:7,reverse(degrees_of_fear)),colorbar=:true,xlabel=L"\{\theta\}")
plot_E = heatmap(matr_E,c=:amp,title=L"\mathrm{nominal\ exchange\ rate}",xticks=(1:3,[L"\mathrm{low}",L"\mathrm{baseline}",L"\mathrm{high}"]),yticks=(1:7,reverse(degrees_of_fear)),colorbar=:true,xlabel=L"\{\theta\}")
l = @layout[a a a{0.4w}; a a a{0.4w}]
plot_all = plot(plot_w,plot_C,plot_r,plot_N_bias,plot_T_bias,plot_gaps,size=(900,600),layout=l,tickfontsize=10,titlefontsize=12,bottom_margin=0.25Plots.cm,top_margin=0.25Plots.cm,left_margin=-0.2Plots.cm)

# %%
png("graphs/alternative_rules_elasticites.png")
# Out:
# "graphs/alternative_rules_elasticites.png"
